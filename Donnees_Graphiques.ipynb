# %%
import pandas as pd
import numpy as n
import matplotlib as plt

# %%
datsrc = pd.read_excel("donnees-synop-essentielles-omm.xlsx", index_col=0)

# %%
datsrc
# Out:
#                                Date.1     Heure  \
# Date
# 2020-01-01T01:00:00+01:00  2020-01-01  01:00:00
# 2020-01-02T01:00:00+01:00  2020-01-02  01:00:00
# 2020-01-03T01:00:00+01:00  2020-01-03  01:00:00
# 2020-01-04T01:00:00+01:00  2020-01-04  01:00:00
# 2020-01-05T01:00:00+01:00  2020-01-05  01:00:00
# ...                               ...       ...
# 2020-10-20T23:00:00+02:00  2020-10-20  23:00:00
# 2020-10-21T23:00:00+02:00  2020-10-21  23:00:00
# 2020-10-22T23:00:00+02:00  2020-10-22  23:00:00
# 2020-10-23T23:00:00+02:00  2020-10-23  23:00:00
# 2020-10-24T23:00:00+02:00  2020-10-24  23:00:00
#
#                            Variation de pression en 3 heures  \
# Date
# 2020-01-01T01:00:00+01:00                                0.0
# 2020-01-02T01:00:00+01:00                              -60.0
# 2020-01-03T01:00:00+01:00                               60.0
# 2020-01-04T01:00:00+01:00                               50.0
# 2020-01-05T01:00:00+01:00                              -60.0
# ...

# %%
datsrc.plot(x="Humidite", y="Temperature")
# Out:
# <AxesSubplot:xlabel='Humidite'>

# %%
datsrc.plot(x="Temperature", y="Vitesse du vent moyen 10 mn")
# Out:
# <AxesSubplot:xlabel='Temperature'>

# %%
datsrc.plot(x="Vitesse du vent moyen 10 mn", y="Humidite")
# Out:
# <AxesSubplot:xlabel='Vitesse du vent moyen 10 mn'>

# %%
datsrc.describe()
# Out:
#        Variation de pression en 3 heures  Type de tendance barom̩trique  \
# count                        2531.000000                     2531.000000
# mean                           -0.339787                        4.414461
# std                           116.656158                        2.713473
# min                          -810.000000                        0.000000
# 25%                           -70.000000                        2.000000
# 50%                             0.000000                        5.000000
# 75%                            70.000000                        7.000000
# max                           890.000000                        8.000000
#
#        Direction du vent moyen 10 mn  Vitesse du vent moyen 10 mn  \
# count                    2531.000000                  2531.000000
# mean                      193.804820                     2.775109
# std                        94.954242                     1.669450
# ...
