# %%
import pandas as pd
import numpy as n
import matplotlib as plt

# %%
datsrc = pd.read_excel("donnees-synop-essentielles-omm.xlsx", index_col=0)

# %%
datsrc
# Out:
#                                      Date  Pression au niveau mer  \
# ID OMM station
# 7621            2020-01-15T22:00:00+01:00                102630.0
# 7621            2020-01-14T13:00:00+01:00                101620.0
# 7621            2020-01-12T16:00:00+01:00                103030.0
# 7621            2020-02-20T19:00:00+01:00                102720.0
# 7621            2020-05-01T14:00:00+02:00                101210.0
# ...                                   ...                     ...
# 7621            2020-05-26T02:00:00+02:00                102870.0
# 7621            2020-05-26T11:00:00+02:00                102820.0
# 7621            2020-05-27T14:00:00+02:00                102490.0
# 7621            2020-05-30T05:00:00+02:00                101480.0
# 7621            2020-02-09T04:00:00+01:00                102620.0
#
#                 Variation de pression en 3 heures  \
# ID OMM station
# 7621                                         80.0
# ...

# %%
datsrc.plot(x="Date", y="Temp̩rature")

# %%
datsrc.plot(x="PSTATM", y="TMMOY")

# %%
datsrc.plot(x="PSTATM", y="TSVMOY")

# %%
datsrc.describe()
# Out:
#        Pression au niveau mer  Variation de pression en 3 heures  \
# count             2531.000000                        2531.000000
# mean            101887.384433                          -0.339787
# std                692.488348                         116.656158
# min              98910.000000                        -810.000000
# 25%             101440.000000                         -70.000000
# 50%             101890.000000                           0.000000
# 75%             102290.000000                          70.000000
# max             103790.000000                         890.000000
#
#        Type de tendance barom̩trique  Direction du vent moyen 10 mn  \
# count                     2531.000000                    2531.000000
# mean                         4.414461                     193.804820
# std                          2.713473                      94.954242
# min                          0.000000                       0.000000
# ...
